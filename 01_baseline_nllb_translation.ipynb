# %% [markdown]
# <a href="https://colab.research.google.com/github/mulata12/NLLB-Tig-Eng-healthcare-mt/blob/main/01_baseline_nllb_translation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
