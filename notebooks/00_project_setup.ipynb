# %% [markdown]
# <a href="https://colab.research.google.com/github/mulata12/NLLB-Tig-Eng-healthcare-mt/blob/main/notebooks/00_project_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/mulata12/NLLB-Tig-Eng-healthcare-mt.git
# Out:
# Cloning into 'NLLB-Tig-Eng-healthcare-mt'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 18 (delta 1), reused 15 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (18/18), done.
# Resolving deltas: 100% (1/1), done.

# %%
# %cd NLLB-Tig-Eng-healthcare-mt
# !ls
# Out:
# [Errno 2] No such file or directory: 'NLLB-Tig-Eng-healthcare-mt'
# /content/NLLB-Tig-Eng-healthcare-mt
# configs  docs	 notebooks  requirements.txt  src
# data	 models  README.md  results

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 12.0 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch

print("Torch version:", torch.__version__)
print("GPU available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# Torch version: 2.10.0+cu128
# GPU available: True
# GPU: Tesla T4

# %%
#!ls /content/drive/MyDrive

# %%
DATA_PATH = "/content/drive/MyDrive/nllb_data"
